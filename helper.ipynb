# %%
# autodl使用学术加速
# !source /etc/network_turbo
# Out:
# 设置成功
# 注意：仅限于学术用途，不承诺稳定性保证

# %%
# 设置git用户信息
# !git config --global user.name "Blue-orz"
# !git config --global user.email "3331390194@qq.com"

# %%
# 将本地修改提交到远程仓库
# !git add .
# !git commit -m "update"
# !git push origin main
